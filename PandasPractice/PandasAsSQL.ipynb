# %%
import pandas as pd
import numpy as np
from pathlib import Path
cur_dir=Path.cwd()
csv_path=str(cur_dir)+"r\\..\\Dataset\\FuelConsumption.csv"
df = pd.read_csv(csv_path)

# %% [markdown]
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
df=df.assign(Engine_volume=df['ENGINESIZE']*df['CYLINDERS']).drop(columns='inplace')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# ...

# %%
df[(df['FUELCONSUMPTION_HWY'] > 7 ) & (df['FUELCONSUMPTION_COMB_MPG'] > 27 ) & (df['CO2EMISSIONS'] > 250 ) & (df['CO2EMISSIONS'].notna() )]
# Out:
#      MODELYEAR  MAKE                      MODEL             VEHICLECLASS  \
# 585       2014  JEEP  GRAND CHEROKEE 4X4 DIESEL           SUV - STANDARD
# 916       2014   RAM                1500 DIESEL  PICKUP TRUCK - STANDARD
#
#      ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 585         3.0          6           A8        D                  11.2
# 916         3.0          6           A8        D                  11.6
#
#      FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 585                  8.4                   9.9                        29
# 916                  8.4                  10.2                        28
#
#      CO2EMISSIONS  Engine_volume
# 585           267           18.0
# 916           275           18.0

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS  Engine_volume
# ...

# %%
df.groupby('TRANSMISSION').size()
# Out:
# TRANSMISSION
# A4      45
# A5      30
# A6     222
# A7      12
# A8      87
# A9       8
# AM5      2
# AM6      6
# AM7     34
# AS4      1
# AS5     10
# AS6    189
# AS7     76
# AS8     80
# AS9      2
# AV      46
# AV6     11
# AV7      5
# AV8      3
# M5      48
# M6     141
# M7       9
# dtype: int64

# %%
df.groupby('TRANSMISSION').count()['MODELYEAR'] #count does not consider nan values
# Out:
# TRANSMISSION
# A4      45
# A5      30
# A6     222
# A7      12
# A8      87
# A9       8
# AM5      2
# AM6      6
# AM7     34
# AS4      1
# AS5     10
# AS6    189
# AS7     76
# AS8     80
# AS9      2
# AV      46
# AV6     11
# AV7      5
# AV8      3
# M5      48
# M6     141
# M7       9
# Name: MODELYEAR, dtype: int64

# %%
df.groupby('TRANSMISSION')['TRANSMISSION'].agg(AverageTrans=np.sum)
# Out:
#                                                    AverageTrans
# TRANSMISSION
# A4            A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4A4...
# A5            A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5A5...
# A6            A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6A6...
# A7                                     A7A7A7A7A7A7A7A7A7A7A7A7
# A8            A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8A8...
# A9                                             A9A9A9A9A9A9A9A9
# AM5                                                      AM5AM5
# AM6                                          AM6AM6AM6AM6AM6AM6
# AM7           AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7AM7A...
# AS4                                                         AS4
# AS5                              AS5AS5AS5AS5AS5AS5AS5AS5AS5AS5
# AS6           AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6AS6A...
# AS7           AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7AS7A...
# ...
